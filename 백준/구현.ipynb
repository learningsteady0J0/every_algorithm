# %% [markdown]
# # 구현은 어떻게 구현 했는지를 중점적으로 작성하면 좋을 것 같다.

# %% [markdown]
# # 백준 1316번 - 그룹 단어 체커
# ### 답안 - https://www.acmicpc.net/submit/1316/68158528
# ### 다른 사람 답안 - https://www.acmicpc.net/source/68149138
# ### 주요 아이디어 -
# 1. 차례대로 문자를 보면서 이전에 본 문자인지 처음보는 문자인지 판단한 후, 이전에 본 문자면 그룹 단어가 아닌 것
# 2.collections.defaultdict를 이용해서 처음 나오는 문자에대해서도 바로 key값을 이용한 처리를 할 수 있게 했다.

# %% [markdown]
# # 백준 18311번 - 왕복
# ### https://www.acmicpc.net/submit/18311/68159928
# ### 주요 아이디어 -
# 1. 천천히 순서대로 문제에서 요구하는 조건을 맞춤

# %% [markdown]
# # 백준 2578번 - 빙고
# ### https://www.acmicpc.net/submit/2578/68161898
# ### 주요 아이디어 -
# 1. 딕셔너리를 통해 map의 각 좌표를 val로 숫자값을 key로 저장하고 숫자값이 들어오면 False로 초기화되어 있는 map_에 바로바로 적용
# 2. 가로, 세로, 왼쪽 대각선, 오른쪽 대각선 각각 체크
