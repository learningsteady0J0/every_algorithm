# %% [markdown]
# # 구현은 어떻게 구현 했는지를 중점적으로 작성하면 좋을 것 같다.

# %% [markdown]
# # 백준 1316번 - 그룹 단어 체커
# ### 답안 - https://www.acmicpc.net/submit/1316/68158528
# ### 다른 사람 답안 - https://www.acmicpc.net/source/68149138
# ### 주요 아이디어 -
# 1. 차례대로 문자를 보면서 이전에 본 문자인지 처음보는 문자인지 판단한 후, 이전에 본 문자면 그룹 단어가 아닌 것
# 2.collections.defaultdict를 이용해서 처음 나오는 문자에대해서도 바로 key값을 이용한 처리를 할 수 있게 했다.
# ---
# 2024.01.23 복습

# %% [markdown]
# # 백준 18311번 - 왕복
# ### https://www.acmicpc.net/submit/18311/68159928
# ### 주요 아이디어 -
# 1. 천천히 순서대로 문제에서 요구하는 조건을 맞춤
# ---
# 2024.01.24 복습

# %% [markdown]
# # 백준 2578번 - 빙고
# ### https://www.acmicpc.net/submit/2578/68161898
# ### 주요 아이디어 -
# 1. 딕셔너리를 통해 map의 각 좌표를 val로 숫자값을 key로 저장하고 숫자값이 들어오면 False로 초기화되어 있는 map_에 바로바로 적용
# 2. 가로, 세로, 왼쪽 대각선, 오른쪽 대각선 각각 체크
# ---
# 2024.01.29

# %% [markdown]
# # 백준 4396번 - 지뢰 찾기
# ### https://www.acmicpc.net/submit/4396/68199877
# ### 주요 아이디어 -
# 1. 문제를 잘 읽기 ( 모든 지뢰가 나타나도록 출력 )
# 2. 지뢰, 사용자 선택 map을 자료구조로 작성
# 3. 근처 지뢰 갯수 찾기 함수 작성
# ---
# 2024.01.30

# %% [markdown]
# # 백준 1244번 - 스위치 켜고 끄기
# ### https://www.acmicpc.net/submit/1244/68202321
# ### 주요 아이디어 -
# 1. 배수배는 for문의 step을 이용하자.
# ---
# 2024.01.31

# %% [markdown]
# # 백준 10994번 - 별찍기19 ( 복습 하기 )
# ### https://www.acmicpc.net/submit/10994/68204281
# ### 주요 아이디어 -
# 1. 반복되어 생성되는 모양 관찰
# 2. 재귀를 이용해 어떻게 구현할지 생각하기
# 3. map_을 이용!
# ---
# 2024.02.01

# %% [markdown]
# # 백준 20436번 - zoac3
# ### https://www.acmicpc.net/submit/20436/68284600
# ### 다른사람 풀이 - https://ywtechit.tistory.com/147
# ### 주요 아이디어 -
# 1. 자판기를 dict로 구현한다
# 2. 왼손과 오른쪽의 현재 위치를 저장하는 변수를 정의한다
# 3. 왼손과 오른손 각각 담당하는 글자를 판별하기 위해 좌표값으로 조건건다
# 4. 위치를 이동하면서 전체 시간을 저장한다.
#
# ### 다른사람풀이 -
# 1. keyboard를 문자열 리스트와 리스트의 index함수를 이용해서 구현함.

# %% [markdown]
# # 백준 6996번 - 애너그램
# ### https://www.acmicpc.net/submit/6996/68451018
# ### 주요 아이디어 -
# 1. 모든 문자가 같은지를 판단하면 된다.
# 2. 따라서 정렬한다음 같은지 판별하면 끝
# ---
# 2024.02.04

# %% [markdown]
# # 백준 5766번 - 할아버지는 유명해!
# ### https://www.acmicpc.net/submit/5766/68757104
# ### 주요 아이디어 -
# 1. collections.defautdict(int)
# 2. set은 자체적으로 정렬과 인덱싱을 쓰지 못한다. 따라서 list(set)을 해준 다음 관리하기.
# ---
# 2024.02.05

# %% [markdown]
# # 복습하기
# # 백준 1931번 : 달팽이
# ### https://www.acmicpc.net/submit/1913/68917272
# ### 주요 아이디어 -
# 1. 1의 위치 index 찾기
# 2. 다음 사각형을 어떻게 그릴지 고민.

# %% [markdown]
# # 백준 20291번 : 파일 정리
# ### https://www.acmicpc.net/problem/20291
# ### 주요 아이디어 -
# 1. collections.defaultdict(int)를 이용해서 각 확장자의 개수 저장
# 2. dict.keys()를 sorrted() 함수를 통해 정렬
# ---
# 2024.02.08

# %% [markdown]
# # 백준 20291번 : 오리
# ### https://www.acmicpc.net/submit/12933/68976231
# ### 주요 아이디어 -
# 1. 각 오리의 stack을 dict형태로 구현.
# 2. 예외처리 잘하기.

# %% [markdown]
# # 백준 15886번 : 내 선물을 받아줘 2
# ### https://www.acmicpc.net/submit/15886/68976929
# ### 주요 아이디어 -
# 1. 'EW' 인 구간에서 무한루프가 생기니 해당 구간만 체크해주면 된다.
# 2. WW, EE의 경우 1에 위반되는데 문제를 잘 읽어보면 밖으로 나갈 수 없다고 하니 저렇게 입력자체가 나오지 않는다.

# %% [markdown]
# # 백준 17413번 - 단어 뒤집기 2
# ### https://www.acmicpc.net/submit/17413/69393089
# ### 주요 아이디어 -
# 1. stack을 이용해서 tag 처리 해주기.

# %% [markdown]
# # 백준 15787번 - 기차가 어둠을 헤치고 은하수를
#
# 1.   항목 추가
# 2.   항목 추가
#
# ### https://www.acmicpc.net/submit/15787/69426498
# ### 주요 아이디어 -
# 1. 쫄지 말것.
# 2. 문제에서 요구하는 것을 그대로 구현할 것.

# %% [markdown]
# # 백준 1283번 - 단축키 지정
# ### https://www.acmicpc.net/submit/1283/69446179
# ### 주요 아이디어 -
# 1. 룰에 따라 단축키를 지정하는 문제.
# 2. 단축기가 지정된 문자에 "[]"를 씌워줘야하는데, 해당 코드를 복잡하게 짰다. 간단하게 str[i][j:] + "[" + str[i][j] + "]" + str[i][j+1:]
#
# 로 인덱싱을 사용해서 문자열을 조합하자!
# ---
# 2024.02.06

# %% [markdown]
# # 백준 10173 - 니모를 찾아서
# ### https://www.acmicpc.net/submit/10173/70432449
# ### 생각의 흐름
# goal : nemo 글자 찾기
# 1. 모든 글자 lower
# 2. in으로 nemo가 있으면 Found 아니면 Missing
# 3. EOI가 나오면 끝

# %% [markdown]
# # 백준 4673번 - 셀프 넘버
# ### https://www.acmicpc.net/submit/4673/69520898
# ### 주요 아이디어 -
# 1. d(n) 함수 구현
# 2. 셀프 넘버 체크

# %% [markdown]
# # 백준 18111번 - 마인크래프트
# ### https://www.acmicpc.net/submit/18111/69523304
# ### 주요 아이디어 -
# 1. 최대 높이에서 시작해서 최소 높이까지 땅고르기의 모든 시간탐색
# 2. 블럭의 총 개수만 필요하기 때문에 dict를 통해 빠르게 연산

# %% [markdown]
# # 백준 3085번 - 사탕 게임
# ### https://www.acmicpc.net/submit/3085/69618095
# ### 주요 아이디어 -
# 1. 처음에 아무것도 수정 안했을 때 전체 행과 열에서 가장 긴 것을 max_count로 초기화
# 2. 각 테이블을 돌면서 상하 좌우를 바꾸고 해당 열과 행에 대해서 가장 긴 것 체크
# 3. 시간 복잡도 : 50 * 50 * 50 * 2 * 2 = 500,000 < 2억. -> 브루트 포스 가능

# %% [markdown]
# # 백준 10703번 - 유성
# ### https://www.acmicpc.net/submit/10703/69797092
# ### 주요 아이디어 -
# 제작되어야 할 모듈
# 1. 유성과 땅이 만난 것을 확인하는 모듈
#  1-1. x좌표 순서대로 땅과 유성의 최소 최대 y좌표를 비교.
# 2. 그때의 그림을 그려주는 모듈
#  2-1. 만났을 때만큼의 *의 y축을 모두 더해주면된다.
#  2.2 땅은 그대로 그리기
#  2.3 나머지부분은 모두 공기로 그리기
# 해당 문제는 시간초과에 애먹었음.
# for문에서 처리되어야하는 것들을 중복해서 for문을 동작시켰는데 하나로 통합시켰고, 문자를 출력할 때 sys.stdout.write를 사용해서 시간을 최대한 단축하여 해결 했다.

# %% [markdown]
# # 백준 13335번 - 트럭
# ### https://www.acmicpc.net/submit/13335/70299326
# ### 생각의 흐름 -
# - goal : 모든 트럭이 다리를 건너는 최단시간 구하기
# - 자료구조 : list -> 다리에 있는 트럭
# - 모듈 : 단위시간 마다 list를 조작해야한다.
# ------1) 다리 위에 있는 트럭 한칸씩 이동하기.
# ------2) 다리의 최대하중이 견디는지 판단하여 새로운 트럭을 들여보내기.
# --------------
# - deque.rotate를 사용해서 쉽게 구현했다.
# - deque.rotate는 배열속에 있는 원소들을 회전시키는 매서드.

# %% [markdown]
# # 백준 21608 - 아기상어
# ### https://www.acmicpc.net/submit/21608/70333225
# ### 생각의 흐름 -
#
# goal : 학생의 만족도의 총 합 구하기
# 구현해야하는 모듈
# 1. 비어 있는 칸 중에서 좋아하는 학생이 인접한 칸에 가장 많은 칸으로 자리를 정한다. -> max_like를 이용해서 각 table을 지나갈 때 비교하기.
# 2. 1을 만족하는 칸이 여러 개이면, 인접한 칸 중에서 비어있는 칸이 가장 많은 칸으로 자리를 정한다. -> max_empty를 이용해서 각 table을 지나갈 때 비교하기.
# 3. 2를 만족하면 행 번호가 작은 칸으로, 그것도 여러개면 열 번호가 가장 작은 칸으로 자리 정하기.
# 4. 이를 종합하면 정해지지 않은 자리에서 상하좌우를 보고 자신이 좋아하는 칸을 우선적으로 보고, 비어 있는 칸을 보고, 행과 열을 따지기. -> max_like, max_empty를 이용하고, 뒤쪽에서 같은 max_like와 max_empty가 나오면 넘어가면 된다.
#
# 자료구조
# 1. table, visited
# 2. max_like, max_empty
#
# - 열심히 풀어보아서 왠만한 예제에선 통과를 했지만, 실패로 떳다. 어디에서 꼬였는지 모르겠다.
# - 정답 코드를 보니 나는 max를 이용했는데 여기선 리스트에 각각의 like, empty, y, x 값을 넣고 정렬을 돌렸다.
#
# # 문제에서 제안한 것을 그대로 구현하는 것을 연습하자.

# %% [markdown]
# # 백준 14719 - 빗물
# ### https://www.acmicpc.net/submit/21608/70333225
# ### 생각의 흐름 -
#
# #### goal : 빗물이 고이는 총량 구하기
#
# - a. wall을 차례대로 입력받는다. 이 때 tallest_wall을 갱신한다.
# - b. 다음 wall의 높이와 비교한다.
#
#     - b.1 tallest_wall이 바뀌면 (이를 오른쪽 기둥으로 생각하고 이전의 값을 모두 계산 후, 이를 왼쪽 기둥으로 다시 생각한다.)
#         - b.1.1 만약 sub_rain의 값이 0이면 그대로 진행한다.
#         - b.1.2 만약 sub_rain의 값이 1이상이라면 sub_rain이 고인 물이 된다. total_rain += sub_rain
#
#     - b.2 tallest_wall이 바뀌지 않으면, 새로 들어온 wall과의 차이를 sub_rain에 기입한다.
#
# - c. array가 다 끝날 때 까지 tallest_wall이 바뀌지 않는다면 마지막 기둥을 오른쪽 기둥으로 생각한다.
#     - c.1 오른쪽 기둥 부터 tallest_wall까지 반대로 간다.
#     - c.1.1 이 때 들어온 wall이 오른쪽 기둥보다 작다면 마지막 기둥 - wall의 값을 sub_rain에 기입한다.
#     - c.1.2 만약 높다면  total_raon += sub_rain을 하고 오른쪽 기둥을 새로들어온 기둥으로 변경한다.
#
# #### 알고리즘을 생각으로 완벽하게 풀 수 있을 때 코드를 구현하니 깔끔하게 잘 작성되었다.

# %% [markdown]
# # 백준 2869 - 달팽이는 올라가고 싶다
# ### https://www.acmicpc.net/submit/2869/70401262
# ### 생각의 흐름 -
#
# #### goal : 달팽이가 정상에 도착하는 날짜 구하기
# - V: 막대기 길이
# - A: 낮에 올라가는 거리
# - B: 밤에 미끄러지는 거리
# - 막대 길이 <= A 면 바로 끝.
# - 막대 길이 - A / (A-B)
# - 1. 나머지가 없다면 몫 + 1 (A를 한번만 더 가면 정상 도착)
# - 2. 나머지가 있다면 몫 + 2 (A-B를 한번 더 거치고 A를 하면 도착)

# %% [markdown]
# # 복습
# # 백준 2504 - 괄호의 값
# ### https://www.acmicpc.net/submit/2504/70462038
# ### 생각의 흐름 -
#
# #### goal : 괄호값을 정의한대로 계산하여 출력
# 1. 열림 괄호는 stack에 넣고, 닫힘 괄호가 나오면 짝을 맞춰주자. 만약 짝이 맞지 않다면 올바르지 않은 괄호이다.
# 2. 전체 값을 계산할 때 가장 작은 괄호의 값은 이때까지의 열림 괄호를 모두 곱한 것과 같다.
# - ex)  [(())] 일 때 중간의 가장 작은 괄호 ()는 [,(,( 의 값이다. 즉 3 * 2 * 2 이다.
# 3. 따라서 열림괄호를 넣을 때마다 값을 곱해주어 가장 작은 괄호의 닫기가 나올 때 더해주고, res값을 나눠주는 연산을 하자.
# 4. 새끼괄호가 아닌 닫힘은 이미 새끼 괄호에서 계산을 했으므로 res값만 나누기를 해준다.

# %% [markdown]
# # 백준 17276 - 배열 돌리기
# ### 걸린 시간 : 20분
# ### https://www.acmicpc.net/submit/17276/71953233
# ### 생각의 흐름
# - goal : 2차원 배열의 회전 후 결과 출력
# 필요한 모듈 :
#     1. 행렬 회전
#         - 1.1 X의 주 대각선을 ((1,1), (2,2), …, (n, n)) 가운데 열 ((n+1)/2 번째 열)로 옮긴다.
#         - 1.2 X의 가운데 열을 X의 부 대각선으로 ((n, 1), (n-1, 2), …, (1, n)) 옮긴다.
#         - 1.3 X의 부 대각선을 X의 가운데 행 ((n+1)/2번째 행)으로 옮긴다.
#         - 1.4 X의 가운데 행을 X의 주 대각선으로 옮긴다.
#         - 1.5 위 네 가지 경우 모두 원소의 기존 순서는 유지 되어야 한다.
#         - 1.6 X의 다른 원소의 위치는 변하지 않는다.
#     2. 각도 변환
#         - 2.1 반시계 방향 : d가 음수면 360 + d
#         - 2.2 45도를 돌리는 함수를 만들었기 때문에 d // 45 후 횟수 정하기

# %% [markdown]
# # 백준 9081 - 단어 맞추기
# ### 걸린 시간 : 25
# ### https://www.acmicpc.net/submit/9081/73092166
# ### 생각의 흐름
# - goal : 단어들을 사전 순으로 정렬할 때 주어진 단어 다음에 나오는 단어 찾기
# - 필요한 모듈 :
#     1. 다음 순서의 값 찾기
#         - 1.1 맨 뒤에서부터 앞의 숫자가 더 작은 곳을 i로 정한다.
#             - 1.1.1 만약 더 작은 곳이 없다면 마지막 단어이므로 주어진단어를 출력한다.
#         - 1.2 맨 뒤에서부터 i값 보다 큰 값을 찾아 j로 정한다.
#         - 1.3 i와 j를 서로 바꾼다.
#         - 1.4 i 뒤에 있는 것들을 순서를 뒤집어준다.
