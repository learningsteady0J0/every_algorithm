# %% [markdown]
# # 백준 18352번 - 특정 거리의 도시 찾기
# ### 답안 - https://www.acmicpc.net/submit/18352/69018057
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 특정 최단거리에 해당하는 인덱스를 출력하도록 하는 응용 문제.

# %% [markdown]
# # 백준 14496번 - 그대, 그머가 되어
# ### 답안 - https://www.acmicpc.net/submit/14496/69018622
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 특정 최단거리에 해당하는 인덱스를 출력하도록 하는 응용 문제.

# %% [markdown]
# # 백준 1446번 - 지름길
# ### 답안 - https://www.acmicpc.net/submit/1446/69066799
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 모든 경로를 추가해주는 아이디어

# %% [markdown]
# # 백준 5972번 - 택배 배송
# ### 답안 - https://www.acmicpc.net/submit/5972/69093889
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 양방향 edge는 그냥 graph 만들 때 양쪽으로 넣어주면 끝!

# %% [markdown]
# # 백준 17396번 - 백도어
# ### 답안 -
# (수정전)https://www.acmicpc.net/submit/17396/69316683
# (수정후)
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 처음에 시야가 있는 것을 미리 관리해주기 위해서 in을 사용하는 코드를 넣었는데 시간이 초과 되었다. 역시 in은 굉장히 연산을 많이 해야하는 것 같다.

# %% [markdown]
# # 백준 14284번 - 간선 이어가기 2
# ### 답안 - https://www.acmicpc.net/submit/14284/69370956
# ### 주요 아이디어 -
# 1. dijkstra 알고리즘
# 2. 무방향 그래프 -> 양방향 그래프.

# %% [markdown]
# # 백준 1261번 - 알고스팟
# ### 답안 - https://www.acmicpc.net/submit/1261/69642975
# ### 주요 아이디어 -
# 1. 알고리즘의 속도를 더 빨리 올리는 대신 코드가 복잡해지면 속도를 조금 포기하더라도 명료하게 짜는게 더 좋은 것 같다.
# 2. 기존엔 그래프에 각 노드를 추가했지만, 여기선 상하좌우를 사용.
