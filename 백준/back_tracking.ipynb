# %% [markdown]
# https://80000coding.oopy.io/85650ea5-e541-4b12-9b86-a958a99b7533
#
# # 아래 내용을 해당 알고리즘 풀 때마다 상기시킬겸 맨위에 주석으로 적어놓는 것도 좋을 것 같다.
#
# ### 백트래킹은 한정조건을 만족하는 모든 경우의 수를 찾는 것.
# ### 여기서 한정 조건은 중복되지 않는 것.

# %% [markdown]
# # 백준 15649번 - N과 M (1)
# ### 답안 - https://replit.com/@learningsteady0/Python#main.py
# ### 주요 아이디어 -
# - 백트래킹은 한정조건을 만족하는 모든 경우의 수를 찾는 것.
# - 여기서 한정 조건은 중복되지 않는 것.
# ---
# 2024.02.20
# 2024.04.02

# %% [markdown]
# # 백준 15654번 - N과 M (5)
# ### 답안 - https://www.acmicpc.net/submit/15654/69973413
# ### 주요 아이디어 -
# - 백트래킹은 한정조건을 만족하는 모든 경우의 수를 찾는 것.
# - 이전 N과 M과 다르게 특정한 수열을 준 다음 M개의 수열을 찾는 문제.
# - answer_list에 중복된 숫자가 있는 것을 판단하기 위해 vistied 자료형을 사용함.
# ---
# 2024.02.22

# %% [markdown]
# # 백준 1759번 - 암호만들기
# ### 답안 - https://www.acmicpc.net/submit/1759/70133684
# ### 생각의 흐름 -
# 1. 브루스 포스에서 한정된 조건이 있으니 백트래킹으로 풀 수 있을 것 같다.
# 2. 오름차순으로 출력을 해야하니 먼저 array를 정렬한다.
# 3. 문자의 개수가 4가 될때까지 반복 후 출력한다.
# 4. 어차피 오름 차순이기 때문에 다음 재귀 함수에 현재 idx + 1을 해주면서 이전 보다 항상 위에 있는 문자들을 출력하면 된다.
#
# 5. 문제를 풀다보니 무조거 모음 1개 자음 2개가 있어야하는 것을 발견했다. depth를 비교해서 출력할 때 해당 조건도 확인하면 된다.
# ---
# 2024.02.28

# %% [markdown]
# # 백준 19663번 - N - Queen
# ### 답안 - https://www.acmicpc.net/submit/9663/70154483
# ### 생각의 흐름 -
# # 1. 접근 방법이 막막해서 그림판으로 그림을 그려보았다. N= 3, 4 까지.
# # 2. 문득 모든 좌표를 리스트에 넣고 퀸을 놓았을 때 놓을 수 없는 좌표들을 지워나가면서 해결하면 된다는 생각이 들었다.
# # 3. 퀸이 놓였을 때 놓을 수 없는 좌표들을 계산하는 모듈
# # 4. 한정된 조건에서 모든 경우의수를 따져야하기때문에 백트래킹을 이용하면 될 것 같다.
# # 5. 위의 생각으로 쭉 작성하였으 중간에 코드가 많이 꼬여서 결국 정답을 보았다.
# ##################################
# # 1. 각 행에는 무조건 하나의 퀸이 있기 때문에 행을 중심으로 알고리즘을 전개해나간다.
# # 2. 자료구조는 1차원 리스트 며 인덱스는 행을 값은 열을 뜻한다.
# # 3. 놓을 수 있는지를 체크 하기 위해 리스트에서 같은 값(열)이 있는지 체크하고 대각선 체크(이전퀸의 행 - 퀸의 행) == (이전 퀸의 열 - 퀸의 열)한다.
#
# # pypy3를 이용해서 풀자 - 시간적인 이득을 더 받을 수 있다.
#
# ---
# 2024.03.16
