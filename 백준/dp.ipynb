# %% [markdown]
# # 백준 2163번 - 초콜릿 자르기
# ### 답안 - https://www.acmicpc.net/submit/2163/68487687
# ### 주요 아이디어 -
# 1. 초콜릿을 가로로 먼저 다 자르고, 다 잘린 개별 초콜릿을 다시 세로로 다 자르면 된다.
# 2. 이를 dp 테이블로 표현했지만, 그냥 식으로 구현해도 되었음
# * 초콜릿 자르는 횟수 공식 = ( N - 1 ) + N X ( M - 1 )

# %% [markdown]
# # 백준 1463번 - 1로 만들기
# ### 답안 - https://www.acmicpc.net/submit/1463/68488134
# ### 주요 아이디어 -
# 1. 전체가 일정한 부분으로 나뉘어 진다.
# 2. dp 테이블은 각 숫자에서의 최소 횟수를 나타낸다.

# %% [markdown]
# # 백준 1309번 - 동물원
# ### 답안 - https://www.acmicpc.net/submit/1309/68490663
# ### 주요 아이디어 -
# 1. 현재 우리에 사자가 없을 때, 왼쪽에 있을 때, 오른쪽에 있을 때를 나누어서 생각하기
# 2. dp table을 3가지의 경우의 수로 생성해서 풀이

# %% [markdown]
# # 백준 2193번 - 이친수
# ### 답안 - https://www.acmicpc.net/submit/2193/68512164
# ### 주요 아이디어 -
# 1. 가장 끝에 나오는 수의 개수를 dp table로 설정하였다.
# 2. 지금 자리수의 0이 나올 경우의 수는 앞자리에서 1이나올 때 0이 나올때 이고, 1이 나올 경우의 수는 0만 있다.
# 3. d[i][0] = d[i-1][1] + d[i-1][0]
# 4. d[i][1] = d[i-1][0]

# %% [markdown]
# # 백준 9095번 - 1, 2, 3 더하기
# ### 답안 - https://www.acmicpc.net/submit/9095/68515373
# ### 주요 아이디어 -
# 1. 각 수를 나열하여 점화식 찾기
# 2. dp table -> (n-1)에서 1 더하기, (n-2)에서 2 더하기, (n-3)에서 3더하기

# %% [markdown]
# # 백준 11726,7번 - 2xn 타일링, 2xn 타일링 2
# ### 답안 - https://www.acmicpc.net/submit/11726/68629760
# ### 답안2 - https://www.acmicpc.net/submit/11727/68630047
# ### 주요 아이디어 -
# 1. 하나씩 나열하다보니 i-2 + i-1 = i 인걸 알게 되었음.
# 2. 하나씩 나열하다보니 2*(i-2) + i-1 = i 인걸 알게 되었음.
# -> i-1 은 하나의 줄을 추가하는 경우의 수만 있고,
#
# -> i-2 은 가로, 사각형을 추가하는 경우의 수가 있어서 * 2를 함.

# %% [markdown]
# # 백준 11722번 : 가장 긴 감소하는 부분 수열
# ### 답안 - https://www.acmicpc.net/submit/11722/68631136
# ### 주요 아이디어 -
# 1. dp table을 해당 원소가 해당하는 가장 긴 수열의 개수로 지정

# %% [markdown]
# # 백준 11055번 : 가장 큰 증가하는 부분 수열
# ### 답안 - https://www.acmicpc.net/submit/11055/68631730
# ### 주요 아이디어 -
# 1. dp table을 해당하는 원소의 수열 최댓값으로 지정
# 2. '수열'이여야 하기 때문에 해당 원소보다 작은 값을 모두 더하면 오답.

# %% [markdown]
# # 백준 11052번 - 카드 구매하기
# ### 답안 - https://www.acmicpc.net/submit/11052/68661232
# ### 주요 아이디어 -
# 1. dp table : 구매한 카드 개수에서 가장 큰 금액
# 2. d[i] = max(d[i], d[i-j] + d[j]) : 모든 경우의 수에 대해서 dp table 작성

# %% [markdown]
# # 백준 1149번 - RGB거리
# ### 답안 - https://www.acmicpc.net/submit/1149/68663594
# ### 주요 아이디어 -
# 1. 앞에 것을 이용해서 어떻게 뒤에 값을 나타낼 수 있을까를 고민.
# 2. 뒷쪽 r의 최솟값은 a[i][0] + min(d[i-1][1], d[i-1][2])

# %% [markdown]
# # 백준 11048번 - 이동하기
# ### 답안 - https://www.acmicpc.net/submit/11048/68710718
# ### 주요 아이디어 -
# 1. 너무 어렵게 생각하지 말자.
# 2. dp에서 중요한건, 점화식. 다음 값이 어떻게 만들어지는지 잘 고민하자
# 3. dp는 해당 지점의 최대 사탕 개수
# 4. dp[y][x]  = map_[y][x] + max(dp[y-1][x], dp[y][x-1], dp[y-1][x-1])

# %% [markdown]
# # **복습하기**
#
# # 백준 2156번 - 포도주 시식
# ### 답안 - https://www.acmicpc.net/submit/2156/68714575
# ### 주요 아이디어 -
# 1. 포도주를 마실 수 있는 경우의 수 3가지를 생각
# 2. 현재 포도주를 마시고, 앞의 포도주를 마실 때 array[i] + array[i-1] + d[i-3]
# 3. 현재 포도주를 마시고, 앞앞의 포도주를 마실 때 array[i] + d[i-2]
# 4. 현재 포도주를 안마실 때 3가지로 나눌 수 있다. d[i-1]

# %% [markdown]
# # 백준 2579번 : 계단 오르기
# ### 답안 - https://www.acmicpc.net/submit/2579/68715260
# ### 주요 아이디어 -
# 1. 마지막 계단을 밟는 2가지 경우의 수
# 1-1. 자신의 앞앞 계단을 밟을 때 : s[i] + d[i-2]
# 1-2. 자신과 자신 앞 계단을 밟을 때 : s[i] + s[i-1] + d[i-3]
# 2. 마지막 계단을 꼭 밟아야하기 때문에 dp table의 마지막 값을 출력

# %% [markdown]
# # 백준 9465번 - 스티커
# ### 답안 - https://www.acmicpc.net/submit/9465/68755823
# ### 주요 아이디어 -
# 1. 앞의 결과에 의존적이기 때문에 dp로 풀 수 있을 것 같음을 알게 됨
# 2. 끝에서부터 가능한 경우의 수를 생각해서 진행했다.
# 3. 총 4가지의 경우의 수를 생각했는데, 곰곰히 더 생각해보니 2개가 중복되는 아이디어라서 다음과 같이 최종 dp table 생성함
#     for x in range(2, N + 1):
#         dp[1][x] = max(
#                        dp[2][x - 1] + map_[1][x],
#                        dp[2][x - 2] + map_[1][x])
#
#         dp[2][x] = max(
#                        dp[1][x - 1] + map_[2][x],
#                        dp[1][x - 2] + map_[2][x])

# %% [markdown]
# # 백준 1965번 : 상자넣기
# ### 답안 - https://www.acmicpc.net/submit/1965/68805394
# ### 주요 아이디어 -
# 1. 오름차순 수열 찾기 문제랑 똑같다.
# 2. dp를 이용하면 되고, dp table엔 해당 번째의 수에서 가장 많은 수의 수열 개수

# %% [markdown]
# # **복습하기**
# # 백준 2293번 : 동전 1
# ### 답안 - https://www.acmicpc.net/submit/2293/68808890
# ### 주요 아이디어 -
# 1. 아이디어가 잘 떠오르지 않았음.
# 2. 차분히 그림을 그려가면서 생각하여 점화식 찾기
# 3. 각 코인을 사용하여 단계별로 경우의 수 계산하기.

# %% [markdown]
# # 백준 1912번 : 연속합
# ### 답안 - https://www.acmicpc.net/submit/1912/69140395
# ### 주요 아이디어 -
# 1. Dp table - 각 순간간의 최대 연속순열의 합
# 2. dp[i] = max(nums[i], nums[i] + dp[i-1])

# %% [markdown]
# # 백준 13549 : 숨박꼭질3
# ### 답안 - https://www.acmicpc.net/submit/13549/69142571
# ### 주요 아이디어 -
# 1. DP table = 각 숫자까지의 가장 빠른 시간
# 2. dp table = K * 2 개
# 3. bfs를 응용해서 dp table 업데이트
# 4. dp tabel의 개수를 처음엔 K*2인줄 알았는데, 문제에서 K아 N보다 크다는 조건이 없었다. 따라서 N과 K중 더 큰 것을 DP table의 크기로 지정.
