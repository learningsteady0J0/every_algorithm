# %%
# 간단한 다익스트라 알고리즘
array = [(1,2,2), (1,3,5), (1,4,1), (2,3,3), (2,4,2), (3,2,3), (3,6,5) ,(4,3,3), (4,5,1), (5,3,1), (5,6,2)]

n, m = 6, 11 # 노드의 개수, 간선의 개수
start = 1 # 시작 노드

INF = 1e9
graph = [[] for _ in range(n+1)]
visited = [0] * (n+1)
distance = [INF] * (n+1)

for i in range(m):
    a, b, c = array[i]
    graph[a].append((b,c))

def get_smallest_mode():
    min_value = INF
    idx = 0
    for i in range(1,n+1):
        if min_value > distance[i] and not visited[i]:
            min_value = distance[i]
            idx = i
    return idx

def dijkstra(start):
    distance[start] = 0
    visited[start] = 1
    for i in graph[start]:
        distance[i[0]] = i[1]

    for j in range(n-1):
        now = get_smallest_node()
        visited[now] = 1
        for k in graph[now]:
            dist = distance[now] + k[1]
            if distance[k[0]] > dist:
                distance[k[0]] = dist
dijkstra(start)

for i in range(1,n+1):
    if distance[i] == INF:
        print("못감")
    else:
        print(distance[i], end=' ')
# Out:
# 0 2 3 1 2 4

# %%
# 간단한 다익스트라 알고리즘
array = [(1,2,2), (1,3,5), (1,4,1), (2,3,3), (2,4,2), (3,2,3), (3,6,5) ,(4,3,3), (4,5,1), (5,3,1), (5,6,2)]

n, m = 6, 11 # 노드의 개수, 간선의 개수
start = 1 # 시작 노드

INF = int(1e9)
graph = [[] for i in range(n+1)]
visited = [0] * (n+1)
distance = [INF] * (n+1)

for i in range(m):
    a, b, c = array[i]
    graph[a].append((b,c))

def get_smallest_node():
    min_value = INF
    index = 0
    for i in range(1, n+1):
        if distance[i] < min_value and not visited[i]:
            min_value = distance[i]
            index = i
    return index

def dijkstra(start):
    distance[start] = 0
    visited[start] = 1
    for j in graph[start]:
        distance[j[0]] = j[1]

    for i in range(n-1):
        now = get_smallest_node()
        visited[now] = 1
        for j in graph[now]:
            cost = distance[now] + j[1]

            if cost < distance[j[0]]:
                distance[j[0]] = cost
dijkstra(start)

for i in range(1, n+1):
    if distance[i] == INF:
        print("못감")
    else:
        print(distance[i], end=' ')
# Out:
# 0 2 3 1 2 4
