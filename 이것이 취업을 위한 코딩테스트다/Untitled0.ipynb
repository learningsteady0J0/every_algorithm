# %%
# 상하좌우
N = 5
commands = ["R", "R", "R", "U", "D", "D"]

def solution(N:int, commands: list[str]) -> list[int]:
    point = [1, 1]
    max = N
    command_x_table = {
        "R" : 1,
        "L" : -1
    }
    command_y_table = {
        "D" : 1,
        "U" : -1
    }

    for command in commands:
        if command in command_x_table:
            change_point = 1
            command_table = command_x_table
        else:
            change_point = 0
            command_table = command_y_table
        if not 0 < point[change_point] + command_table[command] <= max:
            continue
        point[change_point] += command_table[command]
    return point
solution(N, commands)
# Out:
# [3, 4]

# %%
# 시각
N = 5
def solution(N: int) -> int:
    count = 0
    for hour in range(N+1):
        for min in range(60):
            for sec in range(60):
                if '3' in str(hour) + str(min) + str(sec):
                    count += 1

    return count
solution(5)
# Out:
# 11475

# %%
# 왕실의 나이트

input = 'c2'

def solution(input: str) -> int:
    cur_point = [ord(input[0])-ord('a')+1, int(input[1])]
    go_list = [(2, 1), (2, -1), (-2, 1), (-2, -1), (1, 2), (-1, 2), (1, -2), (-1, -2)]
    count = 0
    for go in go_list:
        if 0 < cur_point[0] + go[0] <= 8 and 0 < cur_point[1] + go[1] <= 8:
            count += 1
    return count

solution(input)
# Out:
# 6

# %%
# 게임 개발
N = 4
M = 4
A =1
B = 1
d = 0
map = [[1,1,1,1],
       [1,0,0,1],
       [1,1,0,1],
       [1,1,1,1]]

def solution(N:int, M: int, A: int, B: int, d: int, map: list[list[int]]) -> int:
    d = [[0]*M for _ in range(N)]


solution(N, M, A, B, d, map)
# Out:
# 4
