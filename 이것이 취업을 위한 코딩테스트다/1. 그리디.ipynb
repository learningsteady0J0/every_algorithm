# %% [markdown]
# - 그리디 알고리즘 : 현재 상황에서 지금 당장 좋은 것만 고르는 방법
# - 문제에서 자주나오는 키워드 : '가장 큰 순서대로', '가장 작은 순서대로'
# - 문제 풀이를 위한 최소한의 아이디어를 떠올리고 이것이 정당한지 검토할 수 있어야 한다.

# %%
# 큰 수의 법칙
# 다양한 수로 이루어진 배열이 있을 때 주어진 수들을 M번 더하여 가장 큰 수를 만들자
# 단, 배열의 특정한 인덱스에 해당하는 수가 연속 K번을 초과해서 더해질 수 없다.
# in : 배열의 크기(N): 5, 더해지는 횟수(M): 8, 중첩횟수(K): 3 , [2, 4, 5, 4, 6]
# out : 46

n = 5
m = 8
k = 3
num_list = [2, 4, 5, 4, 6]

def solution(n: int, m: int, k: int, num_list: list[int] ) -> int:



solution(n, m, k, num_list)
# Out:
#   File "<ipython-input-6-11c36e85c496>", line 16
#     solution(n, m, k, num_list)
#     ^
# IndentationError: expected an indented block after function definition on line 12

# %%
# 숫자 카드 게임

input = [[3,1,2], [4,1,4], [2,2,2]]
#input = [[7, 3, 1, 8], [3, 3, 3, 4]]

def solution(input: list[int]) -> int:


solution(input)
# Out:
#   File "<ipython-input-7-c275af4a8dbc>", line 9
#     solution(input)
#     ^
# IndentationError: expected an indented block after function definition on line 6

# %%
import time
# 1이 될 때까지

N = 26
K = 5

def solution(N: int, K: int) -> int:


solution(N, K)
# Out:
#   File "<ipython-input-8-c5f20a73e43e>", line 10
#     solution(N, K)
#     ^
# IndentationError: expected an indented block after function definition on line 7

# %%
# 큰 수의 법칙
# 다양한 수로 이루어진 배열이 있을 때 주어진 수들을 M번 더하여 가장 큰 수를 만들자
# 단, 배열의 특정한 인덱스에 해당하는 수가 연속 K번을 초과해서 더해질 수 없다.
# in : 배열의 크기(N): 5, 더해지는 횟수(M): 8, 중첩횟수(K): 3 , [2, 4, 5, 4, 6]
# out : 46

n = 5
m = 8
k = 3
num_list = [2, 4, 5, 4, 6]

def solution(n: int, m: int, k: int, num_list: list[int] ) -> int:
    num_list.sort(reverse=True)
    print(num_list)
    sum = 0
    k_count = 0

    for _ in range(m):
        if k_count != k:
            sum += num_list[0]
        else:
            sum += num_list[1]
            k_count = 0
            continue
        k_count += 1
    return sum

def solution(n: int, m: int, k: int, num_list: list[int] ) -> int:
    num_list.sort()
    first = num_list[-1]
    second = num_list[-2]

    count = m // (k+1) * k
    count += m % (k+1)

    sum = 0
    sum += count * first
    sum += (m-count) * second

    return sum

solution(n, m, k, num_list)
# Out:
# 46

# %%
# 숫자 카드 게임

input = [[3,1,2], [4,1,4], [2,2,2]]
input = [[7, 3, 1, 8], [3, 3, 3, 4]]

def solution(input: list[int]) -> int:
    return max(map(min,input))
solution(input)
# Out:
# 3

# %%
import time
# 1이 될 때까지

N = 25
K = 5

def solution(N: int, K: int) -> int:
    count = 0

    while N != 1:
        if N % K == 0:
            N = N / K
        else:
            N -= 1
        count += 1
    return count
start_time = time.time()
solution(250, 5)
# Out:
# 4

# %%
# 모험가 길드
N = 5
input = [2,3,1,2,2]

input.sort()

max_x = -1
count = 0
team = 0
for act in input:
    max_x = max(max_x, act)
    count += 1
    if count == max_x:
        count = 0
        team += 1
print(team)
# Out:
# 2

# %%
# 곱하기 혹은 더하기
input = '02984'
sum = int(input[0])

for i in range(1,len(input)):
    num = int(input[i])

    if num <= 1 or sum <= 1:
        sum += num
    else:
        sum *= num
print(sum)
# Out:
# 576

# %%
# 문자열 뒤집기
input = '1011101100101'

count0 = 0
count1 = 0

if input[0] == '1':
    count0 += 1
else:
    count1 += 1

for i in range(len(input)-1):
    if input[i] != input[i+1]:
        if input[i+1] == '1':
            count0 += 1
        else:
            count1 += 1
print(min(count0, count1))
# Out:
# 4

# %%
#만들 수 없는 금액
input = [3,2,1,1,9]
input.sort()
target = 1

for pay in input:
    if target < pay:
        break
    target += pay

print(target)
# Out:
# 8

# %%
while True:
    N, M = map(int, input().split())

    count = 0
    if N == 1:
        count = 1
    elif N == 2:
        count = ((M-1) // 2) + 1
        if count > 4:
            count = 4
    else:
        if M <= 4:
            count = M
        elif 4 < M <= 6:
            count = 4
        else:
            count = M-2
    print(count)
# Out:
# 3
# 4
