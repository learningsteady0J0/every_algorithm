# %%
def GCD(num1: int, num2: int) -> int:
    if num1 % num2 == 0:
        print(2)
        return num2
    else:
        print(1)
        return GCD(num2, num1 % num2)
        print(1)
GCD(192,162)
# Out:
# 1
# 1
# 1
# 2
# 6
