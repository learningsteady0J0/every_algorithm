# %% [markdown]
# 해시 테이블로 구현된 파이썬의 자료형 = 딕셔너리
#
# 파이썬은 오픈 어드레싱을 체택함.
#
#
# 개별 체이닝 방식보다 로드팩터가 적을 때 더 효율적이기 때문

# %%
# 다음의 기능을 제공하는 해시맵을 디자인하라.

class ListNode:
    def __init__(self, key=None, val=None):
        self.key = key
        self.val = val
        self.next = None

import collections
class my_hashmap:
    def __init__(self):

    def put(self, key: int, value: int) -> None:


    def get(self, key: int) -> int:

    def remove(self, key: int) -> None:



hash_map = my_hashmap()
hash_map.put(1,1)
hash_map.put(2,2)
print(hash_map.get(1))
print(hash_map.get(3))
hash_map.put(2,1)
print(hash_map.get(2))
hash_map.remove(2)
print(hash_map.get(2))
# Out:
# 1
# -1
# 1
# -1

# %%
# 보석과 돌
# J는 보석이며, S는 갖고 있는 돌이다. S에는 보석이 몇 개나 있을까? 대소문자는 구분한다.
# in  : J = "aA", S = "aAAbbbb"
# out : 3

j = "aA"
s = "aAAbbbb"

def check_juel(j:str, s:str) -> int:
    pass

def check_juel(j:str, s:str) -> int:
    pass

def check_juel(j:str, s:str) -> int:
    import collections
    sum = 0
    counter = collections.Counter(s)

    for word in j:
        sum += counter[word]
        print(counter[word])
    return sum


check_juel(j, s)
# Out:
# 1
# 2
# 3

# %%
# 중복 문자 없는 가장 긴 부분 문자열
# 중복 문자가 없는 가장 긴 부분 문자열의 길이를 리턴하라
# in  : "ababcdb"
# out : 4 ( "abcd" )
# in  : "pwwkew"
# out : 3 ( "wke" )

input = "ababcdb"
#input = "pwwkew"

def length_of_longest_substring(input:str) -> int:


length_of_longest_substring(input)
# Out:
# 3

# %%
# 상위 K 빈도 요소
# 상위 K번 이상 등장하는 요소를 추출하라
# in  : nums = [1,1,1,2,2,3], k = 2
# out : [1,2]
# 힙 배우고 해보기

# %%
# 다음의 기능을 제공하는 해시맵을 디자인하라.

class ListNode:
    def __init__(self, key=None, value=None):
        self.key = key
        self.value = value
        self.next =None

import collections
class my_hashmap:
    def __init__(self):
        self.size = 1000
        self.table = collections.defaultdict(ListNode)

    def put(self, key: int, value: int) -> None:
        index = key % self.size

        if self.table[index].value is None:
            self.table[index] = ListNode(key, value)
            return

        p = self.table[index]
        while p:
            if p.key == key:
                p.value = value
                return
            if p.next is None:
                break
            p = p.next
        p.next = ListNode(key, value)

    def get(self, key: int) -> int:
        index = key % self.size
        if self.table[index].value is None:
            return -1

        p = self.table[index]
        while p:
            if p.key == key:
                return p.value
            p = p.next
        return -1

    def remove(self, key: int) -> None:
        index = key % self.size
        if self.table[index].value is None:
            return

        p = self.table[index]
        if p.key == key:
            self.table[index] = ListNode() if p.next is None else p.next
            return

        prev = p
        while p:
            if p.key == key:
                prev.next = p.next
                return
            prev, p = p. p.next

hash_map = my_hashmap()
hash_map.put(1,1)
hash_map.put(2,2)
print(hash_map.get(1))
print(hash_map.get(3))
hash_map.put(2,1)
print(hash_map.get(2))
hash_map.remove(2)
print(hash_map.get(2))
# Out:
# 1
# -1
# 1
# -1

# %%
# 보석과 돌
# J는 보석이며, S는 갖고 있는 돌이다. S에는 보석이 몇 개나 있을까? 대소문자는 구분한다.
# in  : J = "aA", S = "aAAbbbb"
# out : 3

j = "aA"
s = "aAAbbbb"

import collections
def check_juel(j:str, s:str) -> int:
    freqs = collections.defaultdict(int)
    count = 0

    for char in s:
        freqs[char] += 1

    for char in j:
        count += freqs[char]
    return count


def check_juel(j:str, s:str) -> int:
    counter = collections.Counter(list(s))
    sum = 0

    for char in j:
        sum += counter[char]
    return sum

def check_juel(j:str, s:str) -> int:
    return sum(char in j for char in s)

check_juel(j, s)
# Out:
# 3

# %%
# 중복 문자 없는 가장 긴 부분 문자열
# 중복 문자가 없는 가장 긴 부분 문자열의 길이를 리턴하라
# in  : "ababcdb"
# out : 4 ( "abcd" )

input = "ababcdb"
#input = "pwwkew"

def length_of_longest_substring(input:str) -> int:
    maps = {}
    max_length = start = 0

    for i, char in enumerate(input):
        if char in maps and maps[char] >= start:
            start = maps[char] + 1
        else:
            max_length = max(max_length, i - start + 1)
        maps[char] = i
    return max_length

length_of_longest_substring(input)
# Out:
# 4

# %%
# 상위 K 빈도 요소
# 상위 K번 이상 등장하는 요소를 추출하라
# in  : nums = [1,1,1,2,2,3], k = 2
# out : [1,2]
# 힙 배우고 해보기
